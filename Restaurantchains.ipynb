# %% [markdown]
# <a href="https://colab.research.google.com/github/rapoluswethasri/SAM-AI-Tech-Task/blob/main/Restaurantchains.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = {
    'Restaurant_Chain': ['KFC', 'Dominos', 'Pizza Hut', 'KFC', 'Dominos', 'Burger King'],
    'Branch': ['Hyderabad', 'Chennai', 'Bangalore', 'Mumbai', 'Delhi', 'Pune'],
    'Ratings': [4.5, 4.2, 4.0, 4.6, 4.1, 3.9],
    'Votes': [500, 450, 300, 550, 400, 280]
}

df = pd.DataFrame(data)

print(df)
# Out:
#   Restaurant_Chain     Branch  Ratings  Votes
# 0              KFC  Hyderabad      4.5    500
# 1          Dominos    Chennai      4.2    450
# 2        Pizza Hut  Bangalore      4.0    300
# 3              KFC     Mumbai      4.6    550
# 4          Dominos      Delhi      4.1    400
# 5      Burger King       Pune      3.9    280

# %%
chain_count = df['Restaurant_Chain'].value_counts()

print(chain_count)
# Out:
# Restaurant_Chain
# KFC            2
# Dominos        2
# Pizza Hut      1
# Burger King    1
# Name: count, dtype: int64

# %%
average_ratings = df.groupby('Restaurant_Chain')['Ratings'].mean()

print(average_ratings)
# Out:
# Restaurant_Chain
# Burger King    3.90
# Dominos        4.15
# KFC            4.55
# Pizza Hut      4.00
# Name: Ratings, dtype: float64

# %%
total_votes = df.groupby('Restaurant_Chain')['Votes'].sum()

print(total_votes)
# Out:
# Restaurant_Chain
# Burger King     280
# Dominos         850
# KFC            1050
# Pizza Hut       300
# Name: Votes, dtype: int64

# %%
plt.figure(figsize=(10,6))

sns.barplot(
    x='Restaurant_Chain',
    y='Ratings',
    data=df,
    palette='Set2'
)

plt.title(
    "Restaurant Chain Ratings Analysis",
    fontsize=18,
    fontweight='bold'
)

plt.xlabel("Restaurant Chain")
plt.ylabel("Ratings")

plt.show()
# Out:
# /tmp/ipykernel_1572/2426858853.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
plt.figure(figsize=(10,6))

sns.barplot(
    x=total_votes.index,
    y=total_votes.values,
    palette='viridis'
)

plt.title(
    "Restaurant Chain Popularity",
    fontsize=18,
    fontweight='bold'
)

plt.xlabel("Restaurant Chain")
plt.ylabel("Total Votes")

plt.show()
# Out:
# /tmp/ipykernel_1572/2556593349.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
